# %%
import pandas as pd

# %%
data = pd.read_csv("Bank_Churn.csv")

# %%
data.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
data_subset  = data[["CreditScore",'Geography', 'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'IsActiveMember', 'EstimatedSalary']]

# %%
data_subset.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    IsActiveMember  EstimatedSalary
# 0               1        101348.88
# 1               1        112542.58
# 2               0        113931.57
# 3               0         93826.63
# 4               1         79084.10

# %%
data_clean = data_subset.copy()
data_clean.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    IsActiveMember  EstimatedSalary
# 0               1        101348.88
# 1               1        112542.58
# 2               0        113931.57
# 3               0         93826.63
# 4               1         79084.10

# %%
import numpy as np

data_clean["Gender"] = np.where(data_clean['Gender']=='Female',1,0)

# %%
data_clean = pd.get_dummies(data_clean, columns=['Geography'], dtype="int",prefix="" ,prefix_sep="")
data_clean.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  IsActiveMember  \
# 0          619       1   42       2       0.00              1               1
# 1          608       1   41       1   83807.86              1               1
# 2          502       1   42       8  159660.80              3               0
# 3          699       1   39       1       0.00              2               0
# 4          850       1   43       2  125510.82              1               1
#
#    EstimatedSalary  France  Germany  Spain
# 0        101348.88       1        0      0
# 1        112542.58       0        0      1
# 2        113931.57       1        0      0
# 3         93826.63       1        0      0
# 4         79084.10       0        0      1

# %%
data_clean.describe()
# Out:
#         CreditScore        Gender           Age        Tenure        Balance  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean     650.528800      0.454300     38.921800      5.012800   76485.889288
# std       96.653299      0.497932     10.487806      2.892174   62397.405202
# min      350.000000      0.000000     18.000000      0.000000       0.000000
# 25%      584.000000      0.000000     32.000000      3.000000       0.000000
# 50%      652.000000      0.000000     37.000000      5.000000   97198.540000
# 75%      718.000000      1.000000     44.000000      7.000000  127644.240000
# max      850.000000      1.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts  IsActiveMember  EstimatedSalary        France  \
# count   10000.000000    10000.000000     10000.000000  10000.000000
# mean        1.530200        0.515100    100090.239881      0.501400
# std         0.581654        0.499797     57510.492818      0.500023
# min         1.000000        0.000000        11.580000      0.000000
# 25%         1.000000        0.000000     51002.110000      0.000000
# 50%         1.000000        1.000000    100193.915000      1.000000
# 75%         2.000000        1.000000    149388.247500      1.000000
# max         4.000000        1.000000    199992.480000      1.000000
#
#             Germany         Spain
# count  10000.000000  10000.000000
# mean       0.250900      0.247700
# std        0.433553      0.431698
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        1.000000      0.000000
# max        1.000000      1.000000

# %%
import seaborn as sns
sns.pairplot(data_clean)

# %%
#data_clean['ProductsPerYear'] = data_clean.NumOfProducts / data_clean.Tenure
data_clean['ProductsPerYear'] = np.where(data_clean['Tenure'] == 0,data_clean.NumOfProducts, data_clean.NumOfProducts / data_clean.Tenure)

# %%
data_clean.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  IsActiveMember  \
# 0          619       1   42       2       0.00              1               1
# 1          608       1   41       1   83807.86              1               1
# 2          502       1   42       8  159660.80              3               0
# 3          699       1   39       1       0.00              2               0
# 4          850       1   43       2  125510.82              1               1
#
#    EstimatedSalary  France  Germany  Spain  ProductsPerYear
# 0        101348.88       1        0      0            0.500
# 1        112542.58       0        0      1            1.000
# 2        113931.57       1        0      0            0.375
# 3         93826.63       1        0      0            2.000
# 4         79084.10       0        0      1            0.500

# %% [markdown]
# ## Cluster 1

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled  = pd.DataFrame(scaler.fit_transform(data_clean),columns=data_clean.columns)
df_scaled.head()
# Out:
#    CreditScore    Gender       Age    Tenure   Balance  NumOfProducts  \
# 0    -0.326221  1.095988  0.293517 -1.041760 -1.225848      -0.911583
# 1    -0.440036  1.095988  0.198164 -1.387538  0.117350      -0.911583
# 2    -1.536794  1.095988  0.293517  1.032908  1.333053       2.527057
# 3     0.501521  1.095988  0.007457 -1.387538 -1.225848       0.807737
# 4     2.063884  1.095988  0.388871 -1.041760  0.785728      -0.911583
#
#    IsActiveMember  EstimatedSalary    France   Germany     Spain  \
# 0        0.970243         0.021886  0.997204 -0.578736 -0.573809
# 1        0.970243         0.216534 -1.002804 -0.578736  1.742740
# 2       -1.030670         0.240687  0.997204 -0.578736 -0.573809
# 3       -1.030670        -0.108918  0.997204 -0.578736 -0.573809
# 4        0.970243        -0.365276 -1.002804 -0.578736  1.742740
#
#    ProductsPerYear
# 0        -0.016781
# 1         0.967674
# 2        -0.262894
# 3         2.936584
# 4        -0.016781

# %%
df_scaled.describe()
# Out:
#         CreditScore        Gender           Age        Tenure       Balance  \
# count  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04
# mean  -4.824585e-16 -2.131628e-18  2.318146e-16 -1.078249e-16 -6.252776e-17
# std    1.000050e+00  1.000050e+00  1.000050e+00  1.000050e+00  1.000050e+00
# min   -3.109504e+00 -9.124191e-01 -1.994969e+00 -1.733315e+00 -1.225848e+00
# 25%   -6.883586e-01 -9.124191e-01 -6.600185e-01 -6.959818e-01 -1.225848e+00
# 50%    1.522218e-02 -9.124191e-01 -1.832505e-01 -4.425957e-03  3.319639e-01
# 75%    6.981094e-01  1.095988e+00  4.842246e-01  6.871299e-01  8.199205e-01
# max    2.063884e+00  1.095988e+00  5.061197e+00  1.724464e+00  2.795323e+00
#
#        NumOfProducts  IsActiveMember  EstimatedSalary        France  \
# count   1.000000e+04    1.000000e+04     1.000000e+04  1.000000e+04
# mean    1.634248e-17   -7.389644e-17    -2.877698e-17  2.096101e-17
# std     1.000050e+00    1.000050e+00     1.000050e+00  1.000050e+00
# min    -9.115835e-01   -1.030670e+00    -1.740268e+00 -1.002804e+00
# 25%    -9.115835e-01   -1.030670e+00    -8.535935e-01 -1.002804e+00
# 50%    -9.115835e-01    9.702426e-01     1.802807e-03  9.972039e-01
# 75%     8.077366e-01    9.702426e-01     8.572431e-01  9.972039e-01
# max     4.246377e+00    9.702426e-01     1.737200e+00  9.972039e-01
#
#             Germany         Spain  ProductsPerYear
# count  1.000000e+04  1.000000e+04     1.000000e+04
# mean  -7.069900e-17 -4.689582e-17     1.957545e-16
# std    1.000050e+00  1.000050e+00     1.000050e+00
# min   -5.787359e-01 -5.738092e-01    -8.043445e-01
# 25%   -5.787359e-01 -5.738092e-01    -6.074535e-01
# 50%   -5.787359e-01 -5.738092e-01    -3.449322e-01
# 75%    1.727904e+00 -5.738092e-01     3.113709e-01
# max    1.727904e+00  1.742740e+00     6.874403e+00

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

inertia_values = []
silhouette_scores = []

for k in range(2,16):
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(df_scaled)
    inertia_values.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(df_scaled, kmeans.labels_, metric='euclidean',sample_size=None))

# %%
# plot the inertia values
import matplotlib.pyplot as plt

# turn the list into a series for plotting
inertia_series = pd.Series(inertia_values, index=range(2, 16))

# plot the data
inertia_series.plot(marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Number of Clusters vs. Inertia");

# %%
kmeans5 = KMeans(n_clusters=5, n_init= 10 , random_state=42)
kmeans5.fit(df_scaled)
# Out:
# KMeans(n_clusters=5, n_init=10, random_state=42)

# %%
from collections import Counter

Counter(kmeans5.labels_)
# Out:
# Counter({np.int32(1): 2350,
#          np.int32(2): 2336,
#          np.int32(3): 2329,
#          np.int32(4): 2299,
#          np.int32(0): 686})

# %%
import seaborn as sns

cluster_centers5 = pd.DataFrame(kmeans5.cluster_centers_, columns=df_scaled.columns)

plt.figure(figsize=(10,2))
sns.heatmap(cluster_centers5, annot=True,cmap="RdBu",fmt='0.1f',linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# ## Cluster 2

# %%
data_geo = data_subset.copy()
data_geo.Gender =   np.where(data_clean['Gender']=='Female',1,0)
data_geo.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
#
#    IsActiveMember  EstimatedSalary
# 0               1        101348.88
# 1               1        112542.58
# 2               0        113931.57
# 3               0         93826.63
# 4               1         79084.10

# %%
data_geo.groupby('Geography').mean()
# Out:
#            CreditScore  Gender        Age    Tenure        Balance  \
# Geography
# France      649.668329     0.0  38.511767  5.004587   62092.636516
# Germany     651.453567     0.0  39.771622  5.009964  119730.116134
# Spain       651.333872     0.0  38.890997  5.032297   61818.147763
#
#            NumOfProducts  IsActiveMember  EstimatedSalary
# Geography
# France          1.530913        0.516753     99899.180814
# Germany         1.519729        0.497409    101113.435102
# Spain           1.539362        0.529673     99440.572281

# %%
data_geo[data_geo.Geography == "France"].Balance.round(-5).value_counts()
# Out:
# Balance
# 0.0         2459
# 100000.0    2123
# 200000.0     432
# Name: count, dtype: int64

# %%
data_geo[data_geo.Geography == "Germany"].Balance.round(-5).value_counts()
# Out:
# Balance
# 100000.0    2176
# 200000.0     314
# 0.0           19
# Name: count, dtype: int64

# %%
data_geo[data_geo.Geography == "Spain"].Balance.round(-5).value_counts()
# Out:
# Balance
# 0.0         1214
# 100000.0    1040
# 200000.0     222
# 300000.0       1
# Name: count, dtype: int64

# %%
df_scaled_no_geo = df_scaled.drop(columns=["France",'Germany','Spain'])
df_scaled_no_geo.head()
# Out:
#    CreditScore    Gender       Age    Tenure   Balance  NumOfProducts  \
# 0    -0.326221  1.095988  0.293517 -1.041760 -1.225848      -0.911583
# 1    -0.440036  1.095988  0.198164 -1.387538  0.117350      -0.911583
# 2    -1.536794  1.095988  0.293517  1.032908  1.333053       2.527057
# 3     0.501521  1.095988  0.007457 -1.387538 -1.225848       0.807737
# 4     2.063884  1.095988  0.388871 -1.041760  0.785728      -0.911583
#
#    IsActiveMember  EstimatedSalary  ProductsPerYear
# 0        0.970243         0.021886        -0.016781
# 1        0.970243         0.216534         0.967674
# 2       -1.030670         0.240687        -0.262894
# 3       -1.030670        -0.108918         2.936584
# 4        0.970243        -0.365276        -0.016781

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

inertia_values = []
silhouette_scores = []

for k in range(2, 16):
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42)
    kmeans.fit(df_scaled_no_geo)
    inertia_values.append(kmeans.inertia_)
    silhouette_scores.append(silhouette_score(df_scaled_no_geo, kmeans.labels_, metric='euclidean', sample_size=None))
# plot the inertia values
import matplotlib.pyplot as plt

# turn the list into a series for plotting
inertia_series = pd.Series(inertia_values, index=range(2, 16))

# plot the data
inertia_series.plot(marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Number of Clusters vs. Inertia");

# %%
kmeans4 = KMeans(n_clusters=4, n_init= 10 , random_state=42)
kmeans4.fit(df_scaled_no_geo)
# Out:
# KMeans(n_clusters=4, n_init=10, random_state=42)

# %%
from collections import Counter

Counter(kmeans4.labels_)
# Out:
# Counter({np.int32(1): 2816,
#          np.int32(2): 2806,
#          np.int32(3): 2302,
#          np.int32(0): 2076})

# %%
import seaborn as sns

cluster_centers4 = pd.DataFrame(kmeans4.cluster_centers_, columns=df_scaled_no_geo.columns)

plt.figure(figsize=(10,2))
sns.heatmap(cluster_centers4, annot=True,cmap="RdBu",fmt='0.1f',linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# ## Cluster Exploration

# %%
data_clean.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  IsActiveMember  \
# 0          619       1   42       2       0.00              1               1
# 1          608       1   41       1   83807.86              1               1
# 2          502       1   42       8  159660.80              3               0
# 3          699       1   39       1       0.00              2               0
# 4          850       1   43       2  125510.82              1               1
#
#    EstimatedSalary  France  Germany  Spain  ProductsPerYear
# 0        101348.88       1        0      0            0.500
# 1        112542.58       0        0      1            1.000
# 2        113931.57       1        0      0            0.375
# 3         93826.63       1        0      0            2.000
# 4         79084.10       0        0      1            0.500

# %%
kmeans4.labels_
# Out:
# array([2, 0, 3, ..., 2, 0, 1], shape=(10000,), dtype=int32)

# %%
data_final = pd.concat([data_clean,data.Exited,pd.Series(kmeans4.labels_, name= 'Cluster')],axis=1)
data_final.head()
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  IsActiveMember  \
# 0          619       1   42       2       0.00              1               1
# 1          608       1   41       1   83807.86              1               1
# 2          502       1   42       8  159660.80              3               0
# 3          699       1   39       1       0.00              2               0
# 4          850       1   43       2  125510.82              1               1
#
#    EstimatedSalary  France  Germany  Spain  ProductsPerYear  Exited  Cluster
# 0        101348.88       1        0      0            0.500       1        2
# 1        112542.58       0        0      1            1.000       0        0
# 2        113931.57       1        0      0            0.375       1        3
# 3         93826.63       1        0      0            2.000       0        0
# 4         79084.10       0        0      1            0.500       0        2

# %%
data_final.groupby('Cluster').mean()
# Out:
#          CreditScore    Gender        Age    Tenure        Balance  \
# Cluster
# 0         650.800578  0.471580  39.139210  1.129576   74306.381773
# 1         646.586648  0.462713  38.560369  5.941761  104193.501204
# 2         653.887028  0.431219  40.087313  5.858517  105158.374893
# 3         651.012598  0.456560  37.747176  6.347524    9607.100339
#
#          NumOfProducts  IsActiveMember  EstimatedSalary    France   Germany  \
# Cluster
# 0             1.676301        0.543834     99725.206257  0.494701  0.266378
# 1             1.237571        0.000000    101656.176534  0.453835  0.338423
# 2             1.239843        1.000000     98548.349066  0.450820  0.317534
# 3             2.110339        0.528236    100383.323206  0.627281  0.048653
#
#             Spain  ProductsPerYear    Exited
# Cluster
# 0        0.238921         1.341000  0.205202
# 1        0.207741         0.251564  0.315696
# 2        0.231646         0.256307  0.166073
# 3        0.324066         0.379543  0.111208
